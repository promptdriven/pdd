# %%
from openai import AzureOpenAI

endpoint = "https://oict-psgd-pcs-openai-gensvc-dev.openai.azure.com/"
model_name = "o4-mini"
deployment = "o4-mini"

subscription_key = "E13HlGGdoJRd5OLrIsIgool07mMUAGgs6fuSUMclonv6uZFBPUxFJQQJ99BDACHYHv6XJ3w3AAABACOG29np"
api_version = "2024-12-01-preview"

client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=endpoint,
    api_key=subscription_key,
)

response = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": "I am going to Paris, what should I see?",
        },
        {
            "role": "assistant",
            "content": "Paris, the capital of France, is known for its stunning architecture, art museums, historical landmarks, and romantic atmosphere. Here are some of the top attractions to see in Paris:\n \n 1. The Eiffel Tower: The iconic Eiffel Tower is one of the most recognizable landmarks in the world and offers breathtaking views of the city.\n 2. The Louvre Museum: The Louvre is one of the world's largest and most famous museums, housing an impressive collection of art and artifacts, including the Mona Lisa.\n 3. Notre-Dame Cathedral: This beautiful cathedral is one of the most famous landmarks in Paris and is known for its Gothic architecture and stunning stained glass windows.\n \n These are just a few of the many attractions that Paris has to offer. With so much to see and do, it's no wonder that Paris is one of the most popular tourist destinations in the world.",
        },
        {
            "role": "user",
            "content": "What is so great about #1?",
        }
    ],
    max_completion_tokens=100000,
    model=deployment
)

print(response.choices[0].message.content)
# Out:
# The Eiffel Tower stands out for several reasons:
#
# • Architectural & engineering marvel
#   – When it was completed in 1889 for the Exposition Universelle (World’s Fair), its 300 m height made it the tallest man‑made structure on Earth.
#   – Its open‑lattice iron framework was revolutionary at the time, demonstrating advances in materials and wind‑resistance design.
#
# • Iconic symbol
#   – Over the past 130+ years it has become the emblem of Paris and, more broadly, of France’s spirit of innovation and culture.
#   – You’ll find it in countless artworks, films, postcards—its silhouette is instantly recognized worldwide.
#
# • Spectacular views
#   – Three viewing levels (including the 2nd‑floor restaurant and the top deck at 276 m) offer 360° panoramas of Paris’s rooftops, the Seine River, Montmartre and beyond.
#   – On a clear day you can see for miles, making it one of the city’s best photo‑op spots.
#
# • Day‑to‑night experience
#   – By day its delicate iron tracery plays with light and shadow; after dusk its 20,000+ bulbs sparkle every hour on the hour.
#   – You can dine “in” or “under” the Tower in one of its two restaurants, or simply picnic on the nearby Champ de Mars lawn.
#
# • Cultural hub
#   – Beyond sightseeing, the Eiffel Tower hosts art installations, pop‑up shops, seasonal exhibitions and even ice‑skating or ice‑sculpture events in winter.
#
# All these elements combine to make it not just a “big metal tower,” but a living monument that captures Paris’s past, present and very romantic atmosphere.
