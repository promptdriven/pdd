# %%
from modules.context_generator import context_generator

# %%
context_generator("/Users/gregtanaka/Documents/PDD/modules/context_generator.py", ".context/context_generator.py", True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 context_generator("/Users/gregtanaka/Documents/PDD/modules/context_generator.py", ".context/context_generator.py", True)
#
# File ~/Documents/PDD/modules/context_generator.py:28, in context_generator(python_filename, output_filename, force)
#      25 chain = prompt_template | llm | StrOutputParser()
#      27 # Run the template
# ---> 28 result = chain.invoke({"python_code": python_code})
#      30 # Step 6: Write the result to the output file
#      31 if os.path.isfile(output_filename) and not force:
#
# File ~/opt/anaconda3/envs/docu_care/lib/python3.12/site-packages/langchain_core/runnables/base.py:2406, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2402 config = patch_config(
#    2403     config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    2404 )
#    2405 if i == 0:
# ...
