# %%
from context_generator import context_generator

# %%
context_generator("/Users/gregtanaka/Documents/PDD/modules/context_generator.py", "../context/context_generator.py", True)
# Out:
# Successfully wrote the example to ../context/context_generator.py.
# True

# %%
context_generator("/Users/gregtanaka/Documents/PDD/modules/preprocess.py", "../context/preprocess.py", True)
# Out:
# Successfully wrote the example to ../context/preprocess.py.
# True
